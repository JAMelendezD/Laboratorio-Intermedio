# %%
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
filenames = sorted(glob.glob('POPG*.txt'))
print(filenames)
# Out:
# ['POPG-0-1.txt', 'POPG-0-2.txt', 'POPG-0-3.txt', 'POPG-10-1.txt', 'POPG-10-2.txt', 'POPG-10-3.txt', 'POPG-100-1.txt', 'POPG-100-2.txt', 'POPG-100-3.txt', 'POPG-20-1.txt', 'POPG-20-2.txt', 'POPG-20-3.txt', 'POPG-30-1.txt', 'POPG-30-2.txt', 'POPG-30-3.txt', 'POPG-40-1.txt', 'POPG-40-2.txt', 'POPG-40-3.txt', 'POPG-50-1.txt', 'POPG-50-2.txt', 'POPG-50-3.txt', 'POPG-60-1.txt', 'POPG-60-2.txt', 'POPG-60-3.txt', 'POPG-70-1.txt', 'POPG-70-2.txt', 'POPG-70-3.txt', 'POPG-80-1.txt', 'POPG-80-2.txt', 'POPG-80-3.txt', 'POPG-90-1.txt', 'POPG-90-2.txt', 'POPG-90-3.txt']

# %%
print(filenames[0])
# Out:
# POPG-0-1.txt

# %%
popg_0_1 = np.loadtxt(fname = filenames[0], skiprows=10)
popg_0_2 = np.loadtxt(fname = filenames[1], skiprows=10)
popg_0_3 = np.loadtxt(fname = filenames[2], skiprows=10)
popg_10_1 = np.loadtxt(fname = filenames[3], skiprows=10)
popg_10_2 = np.loadtxt(fname = filenames[4], skiprows=10)
popg_10_3 = np.loadtxt(fname = filenames[5], skiprows=10)
popg_100_1 = np.loadtxt(fname = filenames[6], skiprows=10)
popg_100_2 = np.loadtxt(fname = filenames[7], skiprows=10)
popg_100_3 = np.loadtxt(fname = filenames[8], skiprows=10)
popg_20_1 = np.loadtxt(fname = filenames[9], skiprows=10)
popg_20_2 = np.loadtxt(fname = filenames[10], skiprows=10)
popg_20_3 = np.loadtxt(fname = filenames[11], skiprows=10)
popg_30_1 = np.loadtxt(fname = filenames[12], skiprows=10)
popg_30_2 = np.loadtxt(fname = filenames[13], skiprows=10)
popg_30_3 = np.loadtxt(fname = filenames[14], skiprows=10)
popg_40_1 = np.loadtxt(fname = filenames[15], skiprows=10)
popg_40_2 = np.loadtxt(fname = filenames[16], skiprows=10)
popg_40_3 = np.loadtxt(fname = filenames[17], skiprows=10)
popg_50_1 = np.loadtxt(fname = filenames[18], skiprows=10)
popg_50_2 = np.loadtxt(fname = filenames[19], skiprows=10)
popg_50_3 = np.loadtxt(fname = filenames[20], skiprows=10)
popg_60_1 = np.loadtxt(fname = filenames[21], skiprows=10)
popg_60_2 = np.loadtxt(fname = filenames[22], skiprows=10)
popg_60_3 = np.loadtxt(fname = filenames[23], skiprows=10)
popg_70_1 = np.loadtxt(fname = filenames[24], skiprows=10)
popg_70_2 = np.loadtxt(fname = filenames[25], skiprows=10)
popg_70_3 = np.loadtxt(fname = filenames[26], skiprows=10)
popg_80_1 = np.loadtxt(fname = filenames[27], skiprows=10)
popg_80_2 = np.loadtxt(fname = filenames[28], skiprows=10)
popg_80_3 = np.loadtxt(fname = filenames[29], skiprows=10)
popg_90_1 = np.loadtxt(fname = filenames[30], skiprows=10)
popg_90_2 = np.loadtxt(fname = filenames[31], skiprows=10)
popg_90_3 = np.loadtxt(fname = filenames[32], skiprows=10)

# %%
plt.plot(popg_0_1[:,0],popg_0_1[:,1])
plt.plot(popg_0_2[:,0],popg_0_2[:,1])
plt.plot(popg_0_3[:,0],popg_0_3[:,1])
plt.show()
